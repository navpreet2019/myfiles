# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\programdata\anaconda3\lib\site-packages (8.0.28)
# Requirement already satisfied: protobuf>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from mysql-connector-python) (3.19.4)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)

# %%
import mysql.connector

# %%
mydb=mysql.connector.connect(
host="localhost",
    user="root",
    password="Pass@123",
    database="world"
)

# %%
print(mydb)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x0000022836297730>

# %%
mycursor=mydb.cursor()

# %%
mycursor.execute("SHOW TABLES")

# %%
for x in mycursor:
    print(x)
# Out:
# ('city',)
# ('country',)
# ('countrylanguage',)

# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd

# %%
def create_server_connection(host_name,user_name,user_password):
    connection=None
    try:
        connection=mysql.connector.connect(
            host=host_name,
            user=user_name,
            passwd=user_password
        )
        print("MYSQL Database connection successful")
    except Error as err:
        print(f"Error: '{err}'")
    return connection
              
# put out MYSQL terminal password
pw="Pass@123"
              
db="mysql_python"
connection=create_server_connection("localhost","root","Pass@123")
# Out:
# MYSQL Database connection successful

# %%
db="mysql_python"
connection=create_server_connection("localhost","root","Pass@123")
# Out:
# MYSQL Database connection successful

# %%
# create mysql_python
def create_database(connection,query):
    cursor=connection.cursor()
    try:
        cursor.execute(query)
        print("Database create successfully")
    except Error as err:
        print(f"Error: '{err}'")
create_database_query="Create database mysql_python"
create_database(connection,create_database_query)
# Out:
# Database create successfully

# %%
def create_db_connection(host_name,user_name,user_password,db_name):
    connection=None
    try:
        connection=mysql.connector.connect(
            host=host_name,
            user=user_name,
            passwd=user_password,
            database=db_name)
        print("MySQL database connection successful")
    except Error as err:
        print(f"Error: '{err}'")
    return connection

# %%
# execute sql queries
def execute_query(connection,query):
    cursor=connection.cursor()
    try:
        cursor.execute(query)
        connection.commit()
        print("Query was successful")
    except Error as err:
        print(f"Error:'{err}'")

# %%
create_orders_table="""
create table orders(
order_id int primary key,
customer_name varchar(30) not null,
product_name varchar(20) not null,
date_ordered date,
quantity int,
unit_price float,
phone_number varchar(20));
"""
# connect to database
connection=create_db_connection("localhost","root","Pass@123",db)
execute_query(connection,create_orders_table)
# Out:
# MySQL database connection successful
# Query was successful

# %%
data_orders="""
insert into orders values
(101,'Aman','Laptop','2018-06-12',2,800,'6293730802'),
(102,'Geetu','Books','2019-02-10',10,12,'8367489124'),
(103,'Anu','Trousers','2019-02-25',5,50,'8976123645'),
(104,'Jeet','T-Shirts','2018-07-14',7,30,'7368145099'),
(105,'Mary','Headphones','2019-05-30',6,48,'8865316698'),
(106,'Danny','Smart TV','2018-08-20',10,300,'7720130449');
"""
connection=create_db_connection("localhost","root","Pass@123",db)
execute_query(connection,data_orders)
# Out:
# MySQL database connection successful
# Query was successful

# %% [markdown]
# # select * from mysql_python.orders;
# # check on mysql

# %%
def read_query(connection,query):
    cursor=connection.cursor()
    result=None
    try:
        cursor.execute(query)
        result=cursor.fetchall()
        return result
    except Error as err:
        print(f"Error:'{err}'")

# %%
# using select stmt
q1="""
select * from orders;
"""
connection=create_db_connection("localhost","root","Pass@123",db)
results=read_query(connection,q1)
for result in results:
    print(result)
# Out:
# MySQL database connection successful
# (101, 'Aman', 'Laptop', datetime.date(2018, 6, 12), 2, 800.0, '6293730802')
# (102, 'Geetu', 'Books', datetime.date(2019, 2, 10), 10, 12.0, '8367489124')
# (103, 'Anu', 'Trousers', datetime.date(2019, 2, 25), 5, 50.0, '8976123645')
# (104, 'Jeet', 'T-Shirts', datetime.date(2018, 7, 14), 7, 30.0, '7368145099')
# (105, 'Mary', 'Headphones', datetime.date(2019, 5, 30), 6, 48.0, '8865316698')
# (106, 'Danny', 'Smart TV', datetime.date(2018, 8, 20), 10, 300.0, '7720130449')

# %%
# displaying two columns
q2="""
select customer_name,phone_number from orders;
"""
connection=create_db_connection("localhost","root","Pass@123",db)
results=read_query(connection,q2)
for result in results:
    print(result)
# Out:
# MySQL database connection successful
# ('Aman', '6293730802')
# ('Geetu', '8367489124')
# ('Anu', '8976123645')
# ('Jeet', '7368145099')
# ('Mary', '8865316698')
# ('Danny', '7720130449')

# %%
# display only year from (date_ordered)
q3="""
select year(date_ordered) from orders;
"""
connection=create_db_connection("localhost","root","Pass@123",db)
results=read_query(connection,q3)
for result in results:
    print(result)
# Out:
# MySQL database connection successful
# (2018,)
# (2019,)
# (2019,)
# (2018,)
# (2019,)
# (2018,)

# %%
#distinct year
q4="""
select distinct year(date_ordered) from orders;
"""
connection=create_db_connection("localhost","root","Pass@123",db)
results=read_query(connection,q4)
for result in results:
    print(result)
# Out:
# MySQL database connection successful
# (2018,)
# (2019,)

# %%
# orders before 31 dec
q5="""
select * from orders where date_ordered < '2018-12-31' 
"""
connection=create_db_connection("localhost","root","Pass@123",db)
results=read_query(connection,q5)
for result in results:
    print(result)
# Out:
# MySQL database connection successful
# (101, 'Aman', 'Laptop', datetime.date(2018, 6, 12), 2, 800.0, '6293730802')
# (104, 'Jeet', 'T-Shirts', datetime.date(2018, 7, 14), 7, 30.0, '7368145099')
# (106, 'Danny', 'Smart TV', datetime.date(2018, 8, 20), 10, 300.0, '7720130449')

# %%
# orders after 31 dec
q6="""
select * from orders where date_ordered > '2018-12-31' 
"""
connection=create_db_connection("localhost","root","Pass@123",db)
results=read_query(connection,q6)
for result in results:
    print(result)
# Out:
# MySQL database connection successful
# (102, 'Geetu', 'Books', datetime.date(2019, 2, 10), 10, 12.0, '8367489124')
# (103, 'Anu', 'Trousers', datetime.date(2019, 2, 25), 5, 50.0, '8976123645')
# (105, 'Mary', 'Headphones', datetime.date(2019, 5, 30), 6, 48.0, '8865316698')

# %%
# expensive product at top(800,300,50,48,30,12)
q7="""
select * from orders order by unit_price desc; 
"""
connection=create_db_connection("localhost","root","Pass@123",db)
results=read_query(connection,q7)
for result in results:
    print(result)
# Out:
# MySQL database connection successful
# (101, 'Aman', 'Laptop', datetime.date(2018, 6, 12), 2, 800.0, '6293730802')
# (106, 'Danny', 'Smart TV', datetime.date(2018, 8, 20), 10, 300.0, '7720130449')
# (103, 'Anu', 'Trousers', datetime.date(2019, 2, 25), 5, 50.0, '8976123645')
# (105, 'Mary', 'Headphones', datetime.date(2019, 5, 30), 6, 48.0, '8865316698')
# (104, 'Jeet', 'T-Shirts', datetime.date(2018, 7, 14), 7, 30.0, '7368145099')
# (102, 'Geetu', 'Books', datetime.date(2019, 2, 10), 10, 12.0, '8367489124')

# %%
# creating dataframe from empty list
from_db=[]
for result in results:
    result=list(result)
    from_db.append(result)
columns=["order_id","customer_name","product_name","date_ordered","quantity",
         "unit_price","phone_number"]
df=pd.DataFrame(from_db,columns=columns)
display(df)
# Out:
#    order_id customer_name product_name date_ordered  quantity  unit_price  \
# 0       101          Aman       Laptop   2018-06-12         2       800.0
# 1       106         Danny     Smart TV   2018-08-20        10       300.0
# 2       103           Anu     Trousers   2019-02-25         5        50.0
# 3       105          Mary   Headphones   2019-05-30         6        48.0
# 4       104          Jeet     T-Shirts   2018-07-14         7        30.0
# 5       102         Geetu        Books   2019-02-10        10        12.0
#
#   phone_number
# 0   6293730802
# 1   7720130449
# 2   8976123645
# 3   8865316698
# 4   7368145099
# 5   8367489124

# %%
# update command
update="""
update orders
set unit_price=45
where order_id=103
"""
connection=create_db_connection("localhost","root","Pass@123",db)
execute_query(connection,update)
# Out:
# MySQL database connection successful
# Query was successful

# %%
#verify
q8="""
select * from orders where order_id=103;
"""
connection=create_db_connection("localhost","root","Pass@123",db)
results=read_query(connection,q8)
for result in results:
    print(result)
# Out:
# MySQL database connection successful
# (103, 'Anu', 'Trousers', datetime.date(2019, 2, 25), 5, 45.0, '8976123645')

# %%
#delete command
delete_order="""
delete from orders
where order_id=105;
"""
connection=create_db_connection("localhost","root","Pass@123",db)
execute_query(connection,delete_order)
# Out:
# MySQL database connection successful
# Query was successful

# %%
#verify
q9="""
select * from orders;
"""
connection=create_db_connection("localhost","root","Pass@123",db)
results=read_query(connection,q9)
for result in results:
    print(result)
# Out:
# MySQL database connection successful
# (101, 'Aman', 'Laptop', datetime.date(2018, 6, 12), 2, 800.0, '6293730802')
# (102, 'Geetu', 'Books', datetime.date(2019, 2, 10), 10, 12.0, '8367489124')
# (103, 'Anu', 'Trousers', datetime.date(2019, 2, 25), 5, 45.0, '8976123645')
# (104, 'Jeet', 'T-Shirts', datetime.date(2018, 7, 14), 7, 30.0, '7368145099')
# (106, 'Danny', 'Smart TV', datetime.date(2018, 8, 20), 10, 300.0, '7720130449')

# %%
#Import necessary libraries and load the data
import pandas as pd

customers = pd.read_csv('Mall_Customers.csv')

# %%
#SQL Statement (Simple SELECT)
'''SELECT * FROM customers'''

#Pandas Equivalant
customers
# Out:
#      CustomerID   Genre  Age  Annual_Income_K_Dollars  Spending_Score_1_to_100
# 0             1    Male   19                       15                       39
# 1             2    Male   21                       15                       81
# 2             3  Female   20                       16                        6
# 3             4  Female   23                       16                       77
# 4             5  Female   31                       17                       40
# ..          ...     ...  ...                      ...                      ...
# 195         196  Female   35                      120                       79
# 196         197  Female   45                      126                       28
# 197         198    Male   32                      126                       74
# 198         199    Male   32                      137                       18
# 199         200    Male   30                      137                       83
#
# [200 rows x 5 columns]

# %%
#SQL Statement (SELECT with limited number of records)
'''SELECT * FROM customers LIMIT 7'''

#Pandas Equivalant
customers.head(7)
# Out:
#    CustomerID   Genre  Age  Annual_Income_K_Dollars  Spending_Score_1_to_100
# 0           1    Male   19                       15                       39
# 1           2    Male   21                       15                       81
# 2           3  Female   20                       16                        6
# 3           4  Female   23                       16                       77
# 4           5  Female   31                       17                       40
# 5           6  Female   22                       17                       76
# 6           7  Female   35                       18                        6

# %%
#SQL Statement (SELECT and WHERE on single condition)
'''SELECT CustomerID FROM customers WHERE Annual_Income_K_Dollars = 16'''

#Pandas Equivalant
customers[customers.Annual_Income_K_Dollars == 16].CustomerID
# Out:
# 2    3
# 3    4
# Name: CustomerID, dtype: int64

# %%
#SELECT...WHERE (Multiple conditions, All columns)
#SQL Statement (SELECT and WHERE on multiple conditions such that all the columns will be selected)
'''SELECT * FROM customers WHERE Annual_Income_K_Dollars = 16 AND Spending_Score_1_to_100 = 6'''

#Pandas Equivalant
customers[(customers.Annual_Income_K_Dollars == 16) & (customers.Spending_Score_1_to_100 == 6)]
# Out:
#    CustomerID   Genre  Age  Annual_Income_K_Dollars  Spending_Score_1_to_100
# 2           3  Female   20                       16                        6

# %%
#SELECT...WHERE(Multiple consitions, Subset of columns)
#SQL Statement (SELECT and WHERE on multiple conditions such that subset of columns will be selected)
'''SELECT Genre, Age, Spending_Score_1_to_100 FROM customers WHERE Annual_Income_K_Dollars = 16 AND 
Spending_Score_1_to_100 = 6'''

#Pandas Equivalant
customers[(customers.Annual_Income_K_Dollars == 16) & (customers.Spending_Score_1_to_100 == 6)][['Genre', 'Age', 'Spending_Score_1_to_100']]
# Out:
#     Genre  Age  Spending_Score_1_to_100
# 2  Female   20                        6

# %%
#AGGREGATE
#SQL Statement (Operation using AGGREGATE functions like MEAN, MIN and MAX)
'''SELECT mean(Age), max(Age), min(Age) FROM customers'''

#Pandas Equivalant
customers.agg({'Age': ['mean', 'max', 'min']})
# Out:
#         Age
# mean  38.85
# max   70.00
# min   18.00

# %%
#DISTINCT
#SQL Statement (Finding distinct values of a column)
'''SELECT DISTINCT Annual_Income_K_Dollars FROM customers'''

#Pandas Equivalant
customers.Annual_Income_K_Dollars.unique()
# Out:
# array([ 15,  16,  17,  18,  19,  20,  21,  23,  24,  25,  28,  29,  30,
#         33,  34,  37,  38,  39,  40,  42,  43,  44,  46,  47,  48,  49,
#         50,  54,  57,  58,  59,  60,  61,  62,  63,  64,  65,  67,  69,
#         70,  71,  72,  73,  74,  75,  76,  77,  78,  79,  81,  85,  86,
#         87,  88,  93,  97,  98,  99, 101, 103, 113, 120, 126, 137],
#       dtype=int64)

# %%
#ORDERBY (Ascending Order)
#SQL Statement (Filtering on Genre called Female & Ordering By Spending_Score_1_to_100)
'''SELECT * FROM customers WHERE Genre = "Female" ORDER BY Spending_Score_1_to_100'''

#Pandas Equivalant
customers[customers.Genre == 'Female'].sort_values('Spending_Score_1_to_100')
# Out:
#      CustomerID   Genre  Age  Annual_Income_K_Dollars  Spending_Score_1_to_100
# 140         141  Female   57                       75                        5
# 22           23  Female   46                       25                        5
# 2             3  Female   20                       16                        6
# 6             7  Female   35                       18                        6
# 136         137  Female   44                       73                        7
# ..          ...     ...  ...                      ...                      ...
# 163         164  Female   31                       81                       93
# 7             8  Female   23                       18                       94
# 167         168  Female   33                       86                       95
# 19           20  Female   35                       23                       98
# 11           12  Female   35                       19                       99
#
# [112 rows x 5 columns]

# %%
#ORDERBY (Descending Order)
#SQL Statement (Filtering on Genre called Female & Ordering By Spending_Score_1_to_100 in DESCENDING order)
'''SELECT * FROM customers WHERE Genre = "Female" ORDER BY Spending_Score_1_to_100 DESC'''

#Pandas Equivalant
customers[customers.Genre == 'Female'].sort_values('Spending_Score_1_to_100', ascending=False)
# Out:
#      CustomerID   Genre  Age  Annual_Income_K_Dollars  Spending_Score_1_to_100
# 11           12  Female   35                       19                       99
# 19           20  Female   35                       23                       98
# 167         168  Female   33                       86                       95
# 7             8  Female   23                       18                       94
# 163         164  Female   31                       81                       93
# ..          ...     ...  ...                      ...                      ...
# 136         137  Female   44                       73                        7
# 6             7  Female   35                       18                        6
# 2             3  Female   20                       16                        6
# 22           23  Female   46                       25                        5
# 140         141  Female   57                       75                        5
#
# [112 rows x 5 columns]

# %%
#GROUPBY (Count)
#SQL Statement (Grouping by Genre & Age and counting each occurence of it)
'''SELECT Genre, Age, count(*) FROM customers GROUPBY Genre, Age'''

#Pandas Equivalant
customers.groupby(['Genre', 'Age']).size().to_frame('Count').reset_index()
# Out:
#      Genre  Age  Count
# 0   Female   18      1
# 1   Female   19      2
# 2   Female   20      2
# 3   Female   21      4
# 4   Female   22      2
# ..     ...  ...    ...
# 82    Male   66      1
# 83    Male   67      3
# 84    Male   68      1
# 85    Male   69      1
# 86    Male   70      2
#
# [87 rows x 3 columns]

# %%
#GROUPBY (Count and Descending order on a column)
# SQL Statement (Grouping by Genre & Age and counting each occurence of it such that Age values are sorted in descending order)
'''SELECT Genre, Age, count(*) FROM customers GROUPBY Genre, Age ORDER BY Age DESC'''

#Pandas Equivalant
customers.groupby(['Genre', 'Age']).size().to_frame('Count').reset_index().sort_values('Age', ascending = False)
# Out:
#      Genre  Age  Count
# 86    Male   70      2
# 85    Male   69      1
# 42  Female   68      2
# 84    Male   68      1
# 83    Male   67      3
# ..     ...  ...    ...
# 2   Female   20      2
# 1   Female   19      2
# 44    Male   19      6
# 0   Female   18      1
# 43    Male   18      3
#
# [87 rows x 3 columns]

# %%
# HAVING

#SQL Statement (Additional filter on Grouped Data by making use of HAVING)
'''SELECT Age, count(*) FROM customers GROUPBY Age HAVING count(*) < 3'''

#Pandas Equivalant
customers.groupby('Age').filter(lambda x: len(x) < 3).groupby('Age').size()
# Out:
# Age
# 26    2
# 41    2
# 42    2
# 44    2
# 51    2
# 52    2
# 53    2
# 55    1
# 56    1
# 57    2
# 58    2
# 63    2
# 64    1
# 65    2
# 66    2
# 69    1
# 70    2
# dtype: int64

# %%
# IN

#SQL Statement (Filter records based on values which are available in the given list )
'''SELECT * FROM customers WHERE Age IN (20, 30, 40)'''

#Pandas Equivalant
customers[customers.Age.isin([20,30,40])]
# Out:
#      CustomerID   Genre  Age  Annual_Income_K_Dollars  Spending_Score_1_to_100
# 2             3  Female   20                       16                        6
# 9            10  Female   30                       19                       72
# 17           18    Male   20                       21                       66
# 28           29  Female   40                       29                       31
# 37           38  Female   30                       34                       73
# 39           40  Female   20                       37                       75
# 77           78    Male   40                       54                       48
# 93           94  Female   40                       60                       40
# 99          100    Male   20                       61                       49
# 122         123  Female   40                       69                       58
# 127         128    Male   40                       71                       95
# 134         135    Male   20                       73                        5
# 157         158  Female   30                       78                       78
# 159         160  Female   30                       78                       73
# 170         171    Male   40                       87                       13
# 175         176  Female   30                       88                       86
# 185         186    Male   30                       99                       97
# 199         200    Male   30                      137                       83

# %%
#NOT IN

#SQL Statement (Filter records based on values which are NOT available in the given list)
'''SELECT * FROM customers WHERE Age NOT IN (20, 30, 40)'''

#Pandas Equivalant
customers[~customers.Age.isin([20,30,40])]
# Out:
#      CustomerID   Genre  Age  Annual_Income_K_Dollars  Spending_Score_1_to_100
# 0             1    Male   19                       15                       39
# 1             2    Male   21                       15                       81
# 3             4  Female   23                       16                       77
# 4             5  Female   31                       17                       40
# 5             6  Female   22                       17                       76
# ..          ...     ...  ...                      ...                      ...
# 194         195  Female   47                      120                       16
# 195         196  Female   35                      120                       79
# 196         197  Female   45                      126                       28
# 197         198    Male   32                      126                       74
# 198         199    Male   32                      137                       18
#
# [182 rows x 5 columns]

# %%
#Top N Observations

#SQL Statement (Identify Top 10 records)
'''SELECT * FROM customers ORDER BY Spending_Score_1_to_100 DESC LIMIT 10'''

#Pandas Equivalant
customers.nlargest(10, columns='Spending_Score_1_to_100')
# Out:
#      CustomerID   Genre  Age  Annual_Income_K_Dollars  Spending_Score_1_to_100
# 11           12  Female   35                       19                       99
# 19           20  Female   35                       23                       98
# 145         146    Male   28                       77                       97
# 185         186    Male   30                       99                       97
# 127         128    Male   40                       71                       95
# 167         168  Female   33                       86                       95
# 7             8  Female   23                       18                       94
# 141         142    Male   32                       75                       93
# 163         164  Female   31                       81                       93
# 33           34    Male   18                       33                       92

# %%
#Top N Observations with Offset
#SQL Statement (Identify Next Top 10 records)
'''SELECT * FROM customers ORDER BY Spending_Score_1_to_100 DESC LIMIT 10 OFFSET 10'''

#Pandas Equivalant
customers.nlargest(20, columns='Spending_Score_1_to_100').tail(10)
# Out:
#      CustomerID   Genre  Age  Annual_Income_K_Dollars  Spending_Score_1_to_100
# 41           42    Male   24                       38                       92
# 173         174    Male   36                       87                       92
# 123         124    Male   39                       69                       91
# 193         194  Female   38                      113                       91
# 149         150    Male   34                       78                       90
# 179         180    Male   35                       93                       90
# 155         156  Female   27                       78                       89
# 135         136  Female   29                       73                       88
# 151         152    Male   39                       78                       88
# 183         184  Female   29                       98                       88

# %%
#UNION ALL AND UNION
shop_customers = pd.read_csv('Shop_Customers.csv')

#SQL Statement (Union two Tables)
'''SELECT * FROM customers WHERE Annual_Income_K_Dollars > 50 UNION ALL SELECT * FROM shop_customers Annual_Income_K_Dollars < 45 '''

#Pandas Equivalant
pd.concat([customers[customers.Annual_Income_K_Dollars > 50], shop_customers[shop_customers.Annual_Income_K_Dollars < 45]])

#If wants to mimic UNION operation then just (append) chain the entire operation with drop_duplicates() method
# Out:
#     CustomerID   Genre  Age  Annual_Income_K_Dollars  Spending_Score_1_to_100
# 74          75    Male   59                       54                       47
# 75          76    Male   26                       54                       54
# 76          77  Female   45                       54                       53
# 77          78    Male   40                       54                       48
# 78          79  Female   23                       54                       52
# ..         ...     ...  ...                      ...                      ...
# 15         216    Male   64                       26                       79
# 16         217  Female   67                       26                       35
# 17         218    Male   67                       27                       66
# 18         219    Male   20                       28                       29
# 19         220  Female   23                       24                       98
#
# [146 rows x 5 columns]

# %%
# JOIN
transactions = pd.read_csv('Mall_Customers_Transactions.csv')

#SQL Statement (Join two Tables)
'''SELECT * FROM customers c JOIN transactions t ON c.CustomerID = t.CustID WHERE c.Genre = "Female" '''

#Pandas Equivalant
customers.merge(transactions[customers.Genre == 'Female'], left_on='CustomerID', right_on='CustID', how='inner')
# Out:
#      CustomerID   Genre  Age  Annual_Income_K_Dollars  \
# 0             3  Female   20                       16
# 1             4  Female   23                       16
# 2             5  Female   31                       17
# 3             6  Female   22                       17
# 4             7  Female   35                       18
# ..          ...     ...  ...                      ...
# 107         192  Female   32                      103
# 108         194  Female   38                      113
# 109         195  Female   47                      120
# 110         196  Female   35                      120
# 111         197  Female   45                      126
#
#      Spending_Score_1_to_100  CustID  Transaction_Dollars  Product_Count
# 0                          6       3                  923             12
# 1                         77       4                  804             20
# 2                         40       5                  397             24
# 3                         76       6                  954             26
# 4                          6       7                  357             20
# ..                       ...     ...                  ...            ...
# 107                       69     192                  768             12
# 108                       91     194                  396             14
# 109                       16     195                  683             10
# 110                       79     196                  953             29
# 111                       28     197                  283             16
#
# [112 rows x 8 columns]

# %%
# INSERT
#SQL Statement (Insert a new record in the table)
'''INSERT INTO customers VALUES(401, 'Male', 50, 30, 20) '''

#Pandas Equivalant
customers = customers.append({'CustomerID':401, 'Genre':'Male', 'Age':50, 'Annual_Income_K_Dollars':30, 'Spending_Score_1_to_100':20}, ignore_index=True)
customers
# Out:
#      CustomerID   Genre  Age  Annual_Income_K_Dollars  Spending_Score_1_to_100
# 0             1    Male   19                       15                       39
# 1             2    Male   21                       15                       81
# 2             3  Female   20                       16                        6
# 3             4  Female   23                       16                       77
# 4             5  Female   31                       17                       40
# ..          ...     ...  ...                      ...                      ...
# 196         197  Female   45                      126                       28
# 197         198    Male   32                      126                       74
# 198         199    Male   32                      137                       18
# 199         200    Male   30                      137                       83
# 200         401    Male   50                       30                       20
#
# [201 rows x 5 columns]

# %%
#UPDATE
#SQL Statement (Update an existing record in the table)
'''UPDATE customers SET Spending_Score_1_to_100 = 7 WHERE Spending_Score_1_to_100 = 6'''

#Pandas Equivalant
customers.loc[customers['Spending_Score_1_to_100'] == 6, 'Spending_Score_1_to_100'] = 7

# %%
#customers = pd.read_csv('Mall_Customers.csv')

#Currently two records with Spending_Score_1_to_100 == 6
customers[(customers.Spending_Score_1_to_100 == 7)]
# Out:
#      CustomerID   Genre  Age  Annual_Income_K_Dollars  Spending_Score_1_to_100
# 2             3  Female   20                       16                        7
# 6             7  Female   35                       18                        7
# 136         137  Female   44                       73                        7

# %%
#DELETE
#SQL Statement (Delete an existing record in the table)
'''DELETE FROM customers WHERE Spending_Score_1_to_100 = 7'''

#Pandas Equivalant
customers = customers.drop(customers[customers.Spending_Score_1_to_100 == 7].index)
