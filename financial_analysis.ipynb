# %%
# will cover
#1. calculate with columns,2. create new columns3. drop columns4. min,max,argmin,argmax,5. Mean
#FINANCIAL DATA ANALYSIS WITH PYTHON
import pandas as pd

# %%
data=pd.read_csv("AAPL.csv",index_col=0,parse_dates=True)

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-29  100.589996  100.690002   98.040001   99.620003   93.514290
# 2014-10-06   99.949997  102.379997   98.309998  100.730003   94.556244
# 2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 2014-10-27  104.849998  108.040001  104.699997  108.000000  101.380676
# ...                ...         ...         ...         ...         ...
# 2018-03-05  175.210007  180.000000  174.270004  179.979996  179.979996
# 2018-03-12  180.289993  183.500000  177.619995  178.020004  178.020004
# 2018-03-19  177.320007  177.470001  164.940002  164.940002  164.940002
# 2018-03-26  168.070007  175.149994  165.190002  167.779999  167.779999
# 2018-03-29  167.804993  171.750000  166.899994  167.779999  167.779999
#
#                Volume
# Date
# 2014-09-29  142718700
# 2014-10-06  280258200
# 2014-10-13  358539800
# ...

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-29  100.589996  100.690002   98.040001   99.620003   93.514290
# 2014-10-06   99.949997  102.379997   98.309998  100.730003   94.556244
# 2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 2014-10-27  104.849998  108.040001  104.699997  108.000000  101.380676
#
#                Volume
# Date
# 2014-09-29  142718700
# 2014-10-06  280258200
# 2014-10-13  358539800
# 2014-10-20  358532900
# 2014-10-27  220230600

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# closing price - open price  =   Daily change
data['Daily chg']=data['Close']-data['Open']

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-29  100.589996  100.690002   98.040001   99.620003   93.514290
# 2014-10-06   99.949997  102.379997   98.309998  100.730003   94.556244
# 2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 2014-10-27  104.849998  108.040001  104.699997  108.000000  101.380676
#
#                Volume  Daily chg
# Date
# 2014-09-29  142718700  -0.969993
# 2014-10-06  280258200   0.780006
# 2014-10-13  358539800  -3.660004
# 2014-10-20  358532900   6.900001
# 2014-10-27  220230600   3.150002

# %%
# normalizing data(in outpot 99.620003-99.620003=1   and 100.730003-99.620003=1.011142) and so on
data['Normalized']=data['Close']/data['Close'].iloc[0]
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-29  100.589996  100.690002   98.040001   99.620003   93.514290
# 2014-10-06   99.949997  102.379997   98.309998  100.730003   94.556244
# 2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 2014-10-27  104.849998  108.040001  104.699997  108.000000  101.380676
#
#                Volume  Daily chg  Normalized
# Date
# 2014-09-29  142718700  -0.969993    1.000000
# 2014-10-06  280258200   0.780006    1.011142
# 2014-10-13  358539800  -3.660004    0.980426
# 2014-10-20  358532900   6.900001    1.056214
# 2014-10-27  220230600   3.150002    1.084120

# %%
# checking closing value
data['Close'].min()
# Out:
# 90.519997

# %%
# verify it from whole data
data.min()
# Out:
# Open          9.239000e+01
# High          9.377000e+01
# Low           8.947000e+01
# Close         9.052000e+01
# Adj Close     8.779682e+01
# Volume        3.839850e+07
# Daily chg    -1.238001e+01
# Normalized    9.086528e-01
# dtype: float64

# %%
# close min position
data['Close'].argmin()
# Out:
# 84

# %%
# checking value at position 84 ,same value( 9.052000e+01)
data.iloc[84]
# Out:
# Open          9.300000e+01
# High          9.377000e+01
# Low           8.947000e+01
# Close         9.052000e+01
# Adj Close     8.779682e+01
# Volume        2.160498e+08
# Daily chg    -2.480003e+00
# Normalized    9.086528e-01
# Name: 2016-05-09 00:00:00, dtype: float64

# %%
# checking max value for close
data['Close'].max()
# Out:
# 179.979996

# %%
# checking position of max value
data['Close'].argmax()
# Out:
# 179

# %%
data.iloc[179:]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-03-05  175.210007  180.000000  174.270004  179.979996  179.979996
# 2018-03-12  180.289993  183.500000  177.619995  178.020004  178.020004
# 2018-03-19  177.320007  177.470001  164.940002  164.940002  164.940002
# 2018-03-26  168.070007  175.149994  165.190002  167.779999  167.779999
# 2018-03-29  167.804993  171.750000  166.899994  167.779999  167.779999
#
#                Volume  Daily chg  Normalized
# Date
# 2018-03-05  139852700   4.769989    1.806665
# 2018-03-12  155417500  -2.269989    1.786991
# 2018-03-19  172670700 -12.380005    1.655692
# 2018-03-26  157898400  -0.290008    1.684200
# 2018-03-29   38398505  -0.024994    1.684200

# %%
# mean value of all Closes
data['Close'].mean()
# Out:
# 127.35266294565217

# %%
# dropping labels
data.drop(labels=['High','Low','Adj Close','Volume'],axis=1)
# Out:
#                   Open       Close  Daily chg  Normalized
# Date
# 2014-09-29  100.589996   99.620003  -0.969993    1.000000
# 2014-10-06   99.949997  100.730003   0.780006    1.011142
# 2014-10-13  101.330002   97.669998  -3.660004    0.980426
# 2014-10-20   98.320000  105.220001   6.900001    1.056214
# 2014-10-27  104.849998  108.000000   3.150002    1.084120
# ...                ...         ...        ...         ...
# 2018-03-05  175.210007  179.979996   4.769989    1.806665
# 2018-03-12  180.289993  178.020004  -2.269989    1.786991
# 2018-03-19  177.320007  164.940002 -12.380005    1.655692
# 2018-03-26  168.070007  167.779999  -0.290008    1.684200
# 2018-03-29  167.804993  167.779999  -0.024994    1.684200
#
# [184 rows x 4 columns]

# %%
pip install pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2021.10.8)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
# Python for Finance :Risk and Return
import numpy as np
import pandas_datareader as pdr
import datetime as dt
import pandas as pd

# %%
# reading data with API from yahoo finance
start=dt.datetime(2020,1,1)
data=pdr.get_data_yahoo("AAPL",start)

# %%
data.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0  73.894325
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  73.175926
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  73.759010
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0  73.412109
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0  74.593033

# %%
data.index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2022-03-10', '2022-03-11', '2022-03-14', '2022-03-15',
#                '2022-03-16', '2022-03-17', '2022-03-18', '2022-03-21',
#                '2022-03-22', '2022-03-22'],
#               dtype='datetime64[ns]', name='Date', length=561, freq=None)

# %%
data.dtypes
# Out:
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Adj Close    float64
# dtype: object

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# converting to numpy
data.to_numpy()
# Out:
# array([[7.51500015e+01, 7.37975006e+01, 7.40599976e+01, 7.50875015e+01,
#         1.35480400e+08, 7.38943253e+01],
#        [7.51449966e+01, 7.41250000e+01, 7.42874985e+01, 7.43574982e+01,
#         1.46322800e+08, 7.31759262e+01],
#        [7.49899979e+01, 7.31875000e+01, 7.34475021e+01, 7.49499969e+01,
#         1.18387200e+08, 7.37590103e+01],
#        ...,
#        [1.66350006e+02, 1.63009995e+02, 1.63509995e+02, 1.65380005e+02,
#         9.58114000e+07, 1.65380005e+02],
#        [1.69419998e+02, 1.64910004e+02, 1.65509995e+02, 1.68820007e+02,
#         8.14684000e+07, 1.68820007e+02],
#        [1.69419998e+02, 1.64910004e+02, 1.65509995e+02, 1.68820007e+02,
#         8.15320070e+07, 1.68820007e+02]])

# %%
arr=data.to_numpy()

# %%
arr.shape
# Out:
# (561, 6)

# %%
len(data)
# Out:
# 561

# %%
# in output you get the scientific notation
# arr[0]=data.head(1 )  output wil be same
arr[0]
# Out:
# array([7.51500015e+01, 7.37975006e+01, 7.40599976e+01, 7.50875015e+01,
#        1.35480400e+08, 7.38943253e+01])

# %%
# first 10 rows,1st col and make copy of it
small=arr[:10,0].copy()

# %%
small
# Out:
# array([75.15000153, 75.14499664, 74.98999786, 75.22499847, 76.11000061,
#        77.60749817, 78.16750336, 79.26750183, 79.39250183, 78.875     ])

# %%
# getting max value of small
np.max(small)
# Out:
# 79.39250183105469

# %%
small.max()
# Out:
# 79.39250183105469

# %%
small.argmax()
# Out:
# 8

# %%
# for getting value
small[small.argmax()]
# Out:
# 79.39250183105469

# %%
# want to calculate return so lets take log of small
np.log(small)
# Out:
# array([4.31948614, 4.31941954, 4.31735474, 4.3204836 , 4.33217967,
#        4.35166405, 4.358854  , 4.37282823, 4.37440393, 4.36786432])

# %%
np.log(data)
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# Date
# 2020-01-02  4.319486  4.301325  4.304876  4.318654  18.724338   4.302636
# 2020-01-03  4.319420  4.305753  4.307943  4.308885  18.801326   4.292866
# 2020-01-06  4.317355  4.293025  4.296571  4.316821  18.589471   4.300803
# 2020-01-07  4.320484  4.309053  4.316955  4.312107  18.505683   4.296089
# 2020-01-08  4.332180  4.307976  4.307976  4.328065  18.698912   4.312047
# ...              ...       ...       ...       ...        ...        ...
# 2022-03-17  5.081404  5.060251  5.066448  5.079041  18.141171   5.079041
# 2022-03-18  5.102789  5.073673  5.078356  5.099744  18.630546   5.099744
# 2022-03-21  5.114094  5.093812  5.096874  5.108246  18.377892   5.108246
# 2022-03-22  5.132381  5.105400  5.109032  5.128833  18.215726   5.128833
# 2022-03-22  5.132381  5.105400  5.109032  5.128833  18.216506   5.128833
#
# [561 rows x 6 columns]

# %%
# for dividing the previous value with next one
data/data.shift()
# Out:
#                 High       Low      Open     Close    Volume  Adj Close
# Date
# 2020-01-02       NaN       NaN       NaN       NaN       NaN        NaN
# 2020-01-03  0.999933  1.004438  1.003072  0.990278  1.080029   0.990278
# 2020-01-06  0.997937  0.987352  0.988693  1.007968  0.809082   1.007968
# 2020-01-07  1.003134  1.016157  1.020593  0.995297  0.919626   0.995297
# 2020-01-08  1.011765  0.998924  0.991062  1.016086  1.213160   1.016086
# ...              ...       ...       ...       ...       ...        ...
# 2022-03-17  1.006250  1.020523  1.009933  1.006454  0.739152   1.006454
# 2022-03-18  1.021615  1.013513  1.011979  1.020919  1.631297   1.020919
# 2022-03-21  1.011369  1.020343  1.018690  1.008538  0.776737   1.008538
# 2022-03-22  1.018455  1.011656  1.012232  1.020801  0.850300   1.020801
# 2022-03-22  1.000000  1.000000  1.000000  1.000000  1.000781   1.000000
#
# [561 rows x 6 columns]

# %%
# calculating %age change
np.sum(np.log(data/data.shift()))
# Out:
# High         0.812895
# Low          0.804075
# Open         0.804156
# Close        0.810179
# Volume      -0.507831
# Adj Close    0.826197
# dtype: float64

# %%
# verify the result of %age change will display same result as claculating  %age change
np.log(data/data.iloc[0]).tail(1)
# Out:
#                 High       Low      Open     Close    Volume  Adj Close
# Date
# 2022-03-22  0.812895  0.804075  0.804156  0.810179 -0.507831   0.826197

# %%
small.shape
# Out:
# (10,)

# %%
small
# Out:
# array([75.15000153, 75.14499664, 74.98999786, 75.22499847, 76.11000061,
#        77.60749817, 78.16750336, 79.26750183, 79.39250183, 78.875     ])

# %%
small.reshape(2,5)
# Out:
# array([[75.15000153, 75.14499664, 74.98999786, 75.22499847, 76.11000061],
#        [77.60749817, 78.16750336, 79.26750183, 79.39250183, 78.875     ]])

# %%
small.reshape(10,1)
# Out:
# array([[75.15000153],
#        [75.14499664],
#        [74.98999786],
#        [75.22499847],
#        [76.11000061],
#        [77.60749817],
#        [78.16750336],
#        [79.26750183],
#        [79.39250183],
#        [78.875     ]])

# %% [markdown]
#                                PORTFOLIOS

# %%
tickers=['AAPL','MSFT','TWTR','IBM']
start=dt.datetime(2020,1,1)
data=pdr.get_data_yahoo(tickers,start)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: 'MSFT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)

# %%
data.head()
# Out:
# Attributes  Adj Close                                  Close             \
# Symbols          AAPL       TWTR         IBM MSFT       AAPL       TWTR
# Date
# 2020-01-02  73.894333  32.299999  115.261642  NaN  75.087502  32.299999
# 2020-01-03  73.175934  31.520000  114.342415  NaN  74.357498  31.520000
# 2020-01-06  73.759018  31.639999  114.138153  NaN  74.949997  31.639999
# 2020-01-07  73.412125  32.540001  114.214737  NaN  74.597504  32.540001
# 2020-01-08  74.593040  33.049999  115.168022  NaN  75.797501  33.049999
#
# Attributes                        High             ...         Low       \
# Symbols            IBM MSFT       AAPL       TWTR  ...         IBM MSFT
# Date                                               ...
# 2020-01-02  129.464630  NaN  75.150002  32.500000  ...  128.843216  NaN
# 2020-01-03  128.432129  NaN  75.144997  32.099998  ...  127.686424  NaN
# 2020-01-06  128.202682  NaN  74.989998  31.709999  ...  127.342255  NaN
# ...

# %%
# want close of Apple,mocrosoft,twitter,ibm
data=data['Adj Close']
data.head()
# Out:
# Symbols          AAPL       TWTR         IBM  MSFT
# Date
# 2020-01-02  73.894333  32.299999  115.261642   NaN
# 2020-01-03  73.175934  31.520000  114.342415   NaN
# 2020-01-06  73.759018  31.639999  114.138153   NaN
# 2020-01-07  73.412125  32.540001  114.214737   NaN
# 2020-01-08  74.593040  33.049999  115.168022   NaN

# %%
# we have share .25,.15,.40,.20 and we have 100000$
portfolios=[.25,.15,.40,.20]

# %%
np.sum(portfolios)
# Out:
# 1.0

# %%
# normalize data
data/data.iloc[0]
# Out:
# Symbols         AAPL      TWTR       IBM  MSFT
# Date
# 2020-01-02  1.000000  1.000000  1.000000   NaN
# 2020-01-03  0.990278  0.975851  0.992025   NaN
# 2020-01-06  0.998169  0.979567  0.990253   NaN
# 2020-01-07  0.993474  1.007430  0.990917   NaN
# 2020-01-08  1.009455  1.023220  0.999188   NaN
# ...              ...       ...       ...   ...
# 2022-03-17  2.173644  1.154799  1.110170   NaN
# 2022-03-18  2.219115  1.169350  1.117111   NaN
# 2022-03-21  2.238061  1.159133  1.111385   NaN
# 2022-03-22  2.284614  1.189783  1.119713   NaN
# 2022-03-22  2.284614  1.189783  1.119713   NaN
#
# [561 rows x 4 columns]

# %%
#we get same result in 1st row
(data/data.iloc[0])*portfolios*100000
# Out:
# Symbols             AAPL          TWTR           IBM  MSFT
# Date
# 2020-01-02  25000.000000  15000.000000  40000.000000   NaN
# 2020-01-03  24756.950560  14637.771456  39680.994447   NaN
# 2020-01-06  24954.220122  14693.498516  39610.108148   NaN
# 2020-01-07  24836.858852  15111.455890  39636.685546   NaN
# 2020-01-08  25236.387404  15348.297222  39967.510336   NaN
# ...                  ...           ...           ...   ...
# 2022-03-17  54341.107377  17321.981479  44406.793573   NaN
# 2022-03-18  55477.865935  17540.248305  44684.421205   NaN
# 2022-03-21  55951.518345  17386.996677  44455.381122   NaN
# 2022-03-22  57115.343197  17846.749789  44788.533222   NaN
# 2022-03-22  57115.343197  17846.749789  44788.533222   NaN
#
# [561 rows x 4 columns]

# %%
# while working with monte carlo simulation
weight=np.random.random(4)
weight/=weight.sum()
weight
# Out:
# array([0.22019981, 0.44147007, 0.30014868, 0.03818144])

# %%
weight.sum()
# Out:
# 1.0000000000000002

# %%
#Volatility has number of different meanings,we use it in relation to price movement,can be thought as equivalent as risk ,
#call as ATR or average true range

#for calculating ATR: we need TR(true range),n means time period employed,H means current High,L means Current Low,Cp means
#previous close
# ticker value is NFLX netflix

# TR=[H-L,|H-Cp|,|L-Cp|]

# VOLATILITY means average true range

#To make money in the financial markets, there must be price movement. ... The speed or degree of change in prices 
#(in either direction) is called volatility. The good news is that as volatility increases, the potential to make more
#money quickly also increases. The bad news is that higher volatility also means higher risk.

import numpy as np
import pandas_datareader as pdr
import datetime as dt
import pandas as pd

# %%
# take data
start=dt.datetime(2020,1,1)
data=pdr.get_data_yahoo("NFLX",start)

# %%
data.head()
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2020-01-02  329.980011  324.779999  326.100006  329.809998  4485800
# 2020-01-03  329.859985  325.529999  326.779999  325.899994  3806900
# 2020-01-06  336.359985  321.200012  323.119995  335.829987  5663100
# 2020-01-07  336.700012  330.299988  336.470001  330.750000  4703200
# 2020-01-08  342.700012  331.049988  331.489990  339.260010  7104500
#
#              Adj Close
# Date
# 2020-01-02  329.809998
# 2020-01-03  325.899994
# 2020-01-06  335.829987
# 2020-01-07  330.750000
# 2020-01-08  339.260010

# %%
# calculating TR
high_low=data['High']-data['Low']
high_low
# Out:
# Date
# 2020-01-02     5.200012
# 2020-01-03     4.329987
# 2020-01-06    15.159973
# 2020-01-07     6.400024
# 2020-01-08    11.650024
#                 ...
# 2022-03-17    18.429993
# 2022-03-18    13.329987
# 2022-03-21    12.880005
# 2022-03-22    19.899994
# 2022-03-22    19.899994
# Length: 561, dtype: float64

# %%
# verify this from output of data.head()
329.980011-324.779999
# Out:
# 5.200012000000015

# %%
#Cp means previous close
# for previous value use shift() and take abs as in formula above
high_cp=np.abs(data['High']-data['Close'].shift())
high_cp
# Out:
# Date
# 2020-01-02          NaN
# 2020-01-03     0.049988
# 2020-01-06    10.459991
# 2020-01-07     0.870026
# 2020-01-08    11.950012
#                 ...
# 2022-03-17    15.779999
# 2022-03-18    10.399994
# 2022-03-21     1.220001
# 2022-03-22    12.070007
# 2022-03-22     3.739990
# Length: 561, dtype: float64

# %%
# verify it , no previous for 1st row ,so using 2nd
329.859985-329.809998
# Out:
# 0.04998699999998735

# %%
low_cp=np.abs(data['Low']-data['Close'].shift())
low_cp
# Out:
# Date
# 2020-01-02          NaN
# 2020-01-03     4.279999
# 2020-01-06     4.699982
# 2020-01-07     5.529999
# 2020-01-08     0.299988
#                 ...
# 2022-01-13    18.959961
# 2022-01-14     7.320007
# 2022-01-18    17.010010
# 2022-01-19     0.289978
# 2022-01-20     0.950012
# Length: 518, dtype: float64

# %%
#in formula using abs value
325.529999-329.809998
# Out:
# -4.279999000000032

# %%
# concatenate all
df=pd.concat([high_low,high_cp,low_cp],axis=1)
df.head()
# Out:
#                     0          1         2
# Date
# 2020-01-02   5.200012        NaN       NaN
# 2020-01-03   4.329987   0.049988  4.279999
# 2020-01-06  15.159973  10.459991  4.699982
# 2020-01-07   6.400024   0.870026  5.529999
# 2020-01-08  11.650024  11.950012  0.299988

# %%
# true range
true_range=np.max(df,axis=1)
true_range
# Out:
# Date
# 2020-01-02     5.200012
# 2020-01-03     4.329987
# 2020-01-06    15.159973
# 2020-01-07     6.400024
# 2020-01-08    11.950012
#                 ...
# 2022-01-13    22.529968
# 2022-01-14    26.489990
# 2022-01-18    17.010010
# 2022-01-19    12.700012
# 2022-01-20    10.750000
# Length: 518, dtype: float64

# %%
# rolling function takes a window of 14  ,In very simple words we take a window size of k at a time and perform some desired mathematical operation on it.
average_true_range=true_range.rolling(14).mean()
average_true_range
# Out:
# Date
# 2020-01-02          NaN
# 2020-01-03          NaN
# 2020-01-06          NaN
# 2020-01-07          NaN
# 2020-01-08          NaN
#                 ...
# 2022-01-13    15.484283
# 2022-01-14    16.965711
# 2022-01-18    17.557857
# 2022-01-19    17.800716
# 2022-01-20    17.849287
# Length: 518, dtype: float64

# %%
#2nd method ,will get same result
true_range.rolling(14).sum()/14
# Out:
# Date
# 2020-01-02          NaN
# 2020-01-03          NaN
# 2020-01-06          NaN
# 2020-01-07          NaN
# 2020-01-08          NaN
#                 ...
# 2022-01-13    15.484283
# 2022-01-14    16.965711
# 2022-01-18    17.557857
# 2022-01-19    17.800716
# 2022-01-20    17.849287
# Length: 518, dtype: float64

# %%
# Visualize
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# graph shows volatility (rise)
fig,ax=plt.subplots()
average_true_range.plot(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %%
#plotting close as well,setting secondary_y=True means I want both ATR and Price
fig,ax=plt.subplots()
average_true_range.plot(ax=ax)
ax2=data['Close'].plot(ax=ax,secondary_y=True,alpha=.3)
ax.set_ylabel("ATR")
ax2.set_ylabel("Price")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Price')

# %%
# Sharpe Ratio= represents both risk and return ,  and is used to help investors understand the return of an investment 
#compared to its risk.

#Sharp Ratio(SR)= Rp-Rf/ std of portfolios(or the risk)
# Rp is return of portfolio
#Rf is risk free return
#SHARPE RATIO

#Sharpe ratio is used to evaluate the risk-adjusted performance of a mutual fund. Basically, this ratio tells an investor
#how much extra return he will receive on holding a risky asset.
import pandas as pd
import pandas_datareader as pdr
import numpy as np
import datetime as dt

# %%
tickers=['AAPL','MSFT','TWTR','IBM']
start=dt.datetime(2020,1,1)
data=pdr.get_data_yahoo(tickers,start)

# %%
data.head()
# Out:
# Attributes  Adj Close                                         Close  \
# Symbols          AAPL        MSFT       TWTR         IBM       AAPL
# Date
# 2020-01-02  73.894333  157.289841  32.299999  115.261658  75.087502
# 2020-01-03  73.175911  155.331329  31.520000  114.342430  74.357498
# 2020-01-06  73.759010  155.732849  31.639999  114.138145  74.949997
# 2020-01-07  73.412125  154.312897  32.540001  114.214745  74.597504
# 2020-01-08  74.593048  156.770859  33.049999  115.168022  75.797501
#
# Attributes                                          High              ...  \
# Symbols           MSFT       TWTR         IBM       AAPL        MSFT  ...
# Date                                                                  ...
# 2020-01-02  160.619995  32.299999  129.464630  75.150002  160.729996  ...
# 2020-01-03  158.619995  31.520000  128.432129  75.144997  159.949997  ...
# 2020-01-06  159.029999  31.639999  128.202682  74.989998  159.100006  ...
# ...

# %%
# we need Adj CLose
data=data['Adj Close']
data
# Out:
# Symbols           AAPL        MSFT       TWTR         IBM
# Date
# 2020-01-02   73.894333  157.289841  32.299999  115.261658
# 2020-01-03   73.175911  155.331329  31.520000  114.342430
# 2020-01-06   73.759010  155.732849  31.639999  114.138145
# 2020-01-07   73.412125  154.312897  32.540001  114.214745
# 2020-01-08   74.593048  156.770859  33.049999  115.168022
# ...                ...         ...        ...         ...
# 2022-03-17  160.619995  295.220001  37.299999  127.959999
# 2022-03-18  163.979996  300.429993  37.770000  128.759995
# 2022-03-21  165.380005  299.160004  37.439999  128.100006
# 2022-03-22  168.820007  304.059998  38.430000  129.059998
# 2022-03-22  168.820007  304.059998  38.430000  129.059998
#
# [561 rows x 4 columns]

# %%
portfolio=[.25,.15,.40,.20]
np.sum(portfolio)
# Out:
# 1.0

# %%
# %age change
data/data.shift()
# Out:
# Symbols         AAPL      MSFT      TWTR       IBM
# Date
# 2020-01-02       NaN       NaN       NaN       NaN
# 2020-01-03  0.990278  0.987548  0.975851  0.992025
# 2020-01-06  1.007968  1.002585  1.003807  0.998213
# 2020-01-07  0.995297  0.990882  1.028445  1.000671
# 2020-01-08  1.016086  1.015928  1.015673  1.008346
# ...              ...       ...       ...       ...
# 2022-03-17  1.006454  1.002819  1.054566  1.007242
# 2022-03-18  1.020919  1.017648  1.012601  1.006252
# 2022-03-21  1.008538  0.995773  0.991263  0.994874
# 2022-03-22  1.020801  1.016379  1.026442  1.007494
# 2022-03-22  1.000000  1.000000  1.000000  1.000000
#
# [561 rows x 4 columns]

# %%
# sum of all %age changes
np.sum(np.log(data/data.shift())*portfolio,axis=1)
# Out:
# Date
# 2020-01-02    0.000000
# 2020-01-03   -0.015701
# 2020-01-06    0.003534
# 2020-01-07    0.008801
# 2020-01-08    0.014243
#                 ...
# 2022-03-17    0.024726
# 2022-03-18    0.014055
# 2022-03-21   -0.003048
# 2022-03-22    0.019517
# 2022-03-22    0.000000
# Length: 561, dtype: float64

# %%
#Log Return is one of three methods for calculating return and it assumes returns are compounded continuously rather than
#across sub-periods. 

#It is calculated by taking the natural log of the ending value divided by the beginning value.

#The simple return of a portfolio is the weighted sum of the simple returns of the constituents of the portfolio. 

#The log return for a time period is the sum of the log returns of  partitions of the time period. For example the log
#return  for a year is the sum of the log returns of the days within the year.

log_return=np.sum(np.log(data/data.shift())*portfolio,axis=1)
log_return
# Out:
# Date
# 2020-01-02    0.000000
# 2020-01-03   -0.015701
# 2020-01-06    0.003534
# 2020-01-07    0.008801
# 2020-01-08    0.014243
#                 ...
# 2022-03-17    0.024726
# 2022-03-18    0.014055
# 2022-03-21   -0.003048
# 2022-03-22    0.019517
# 2022-03-22    0.000000
# Length: 561, dtype: float64

# %%
#Visualize
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# this shows how many days our portfolio is close to 0
fig,ax=plt.subplots()
log_return.hist(bins=50,ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
# standard deviation of portfolio
log_return.std()
# Out:
# 0.02173146266992793

# %%
log_return.mean()
# Out:
# 0.0007086318345752386

# %%
sharp_ratio=log_return.mean()/log_return.std()
sharp_ratio
# Out:
# 0.032608565992009626

# %%
# analysed sharp ratio(**.5 means sqroot and lifting to power of 5)
# 252 trading days in year
asr=sharp_ratio*252**.5
asr
# Out:
# 0.5176449373517742

# %%
# compare it with other portfolios and optimize portfolios
weight=np.random.random(4)
weight/=weight.sum()
weight
# Out:
# array([0.40942523, 0.07776009, 0.37296201, 0.13985267])

# %%
log_return2=np.sum(np.log(data/data.shift())*weight,axis=1)
log_return2
# Out:
# Date
# 2020-01-02    0.000000
# 2020-01-03   -0.015211
# 2020-01-06    0.004617
# 2020-01-07    0.007912
# 2020-01-08    0.014725
#                 ...
# 2022-03-17    0.023677
# 2022-03-18    0.015379
# 2022-03-21   -0.000840
# 2022-03-22    0.020470
# 2022-03-22    0.000000
# Length: 561, dtype: float64

# %%
sharp_ratio2=log_return2.mean()/log_return2.std()
sharp_ratio2
# Out:
# 0.038060445476118414

# %%
asr2=sharp_ratio2*252**.5
asr
# Out:
# 0.5176449373517742

# %%
#Monte Carlo Simulation and Efficient Frontier
#Applying Monte carlo simulation on portfolis using shape ratio
#creating efficient frontier based on Sharp Ratio
#MONTE CARLO SIMULATION

#Monte Carlo Simulation is a statistical method applied in financial modeling. ... The simulation relies on the
#repetition of random samples to achieve numerical results. It can be used to understand the effect of uncertainty and 
#randomness in forecasting models.

#Monte Carlo Simulation, also known as the Monte Carlo Method or a multiple probability simulation, is a mathematical
#technique, which is used to estimate the possible outcomes of an uncertain event.

import numpy as np

# %%
#Monte Carlo Simulation is a great tool to master. It can be used to simulate risk and uncertainty that can affect 
#the outcome of different decision options.

#Simply said, if there are too many variables affecting the outcome, then it can simulate them and 
#find the optimal based on the values.

#It is a technique used to understand the impact of risk and uncertainty in prediction and forecasting models.
#You roll two dice. 

#When you roll 7 means 6 , then you gain 5 dollars.
#If you roll anything else than 7 means 6, you lose 1 dollar.

# %%
#The efficient frontier is the set of optimal portfolios that offer the highest expected return for a defined level of risk
#or the lowest risk for a given level of expected return. 

#Portfolios that lie below the efficient frontier are sub-optimal
#because they do not provide enough return for the level of risk.

# %%
# (1,7,2) 7 is exclusive means 6 here and taking it 2 times
# with monte carlo you are simulating randomness
def roll_dice():
    return np.sum(np.random.randint(1,7,2))

# %%
roll_dice()
# Out:
# 7

# %%
#When you roll 7, then you gain 5 dollars.
#If you roll anything else than 7, you lose 1 dollar.
#results = np.zeros(2) means you are recording in results how many wins and how many losses 

def monte_carlo_simulation(runs=1000):
    results = np.zeros(2)
    for _ in range(runs):
        if roll_dice() == 7:
            results[0] += 1
        else:
            results[1] += 1
    return results

# %%
# these are values of result[0] and result[1] for wins and losses
# we get 174*5 and lose 826*1
monte_carlo_simulation()
# Out:
# array([163., 837.])

# %%
# [0] for getting first entry
results=np.zeros(1000)
for i in range(1000):
    results[i]=monte_carlo_simulation()[0]
results
# Out:
# array([156., 178., 156., 181., 155., 179., 149., 173., 158., 166., 167.,
#        157., 162., 188., 168., 169., 165., 166., 166., 191., 180., 171.,
#        176., 161., 172., 143., 157., 182., 153., 169., 168., 152., 172.,
#        176., 160., 170., 150., 159., 156., 164., 168., 167., 160., 167.,
#        158., 171., 175., 171., 159., 146., 148., 159., 179., 177., 143.,
#        147., 167., 167., 165., 161., 168., 170., 161., 167., 158., 149.,
#        159., 183., 168., 177., 158., 147., 181., 154., 173., 169., 146.,
#        180., 157., 187., 170., 149., 161., 152., 184., 162., 185., 171.,
#        164., 160., 171., 170., 174., 167., 152., 157., 180., 160., 178.,
#        178., 176., 161., 163., 162., 152., 154., 168., 157., 181., 174.,
#        172., 177., 168., 158., 161., 172., 169., 187., 170., 181., 172.,
#        170., 165., 149., 172., 161., 162., 161., 182., 157., 155., 168.,
#        146., 161., 163., 163., 170., 187., 175., 169., 174., 160., 180.,
# ...

# %%
# Visualization

import matplotlib.pyplot as plt
# %matplotlib notebook
 
fig, ax = plt.subplots()
ax.hist(results, bins=15)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([  4.,   1.,  16.,  47.,  78., 120., 167., 146., 162., 106.,  74.,
#          48.,  23.,   4.,   4.]),
#  array([129.        , 134.06666667, 139.13333333, 144.2       ,
#         149.26666667, 154.33333333, 159.4       , 164.46666667,
#         169.53333333, 174.6       , 179.66666667, 184.73333333,
#         189.8       , 194.86666667, 199.93333333, 205.        ]),
#  <BarContainer object of 15 artists>)

# %%
# 5 $ i get
results.mean()*5
# Out:
# 830.985

# %%
# so I got 4 $ 836-832=4
1000-results.mean()
# Out:
# 833.803

# %%
results.mean()/1000
# Out:
# 0.166197

# %%
d1 = np.arange(1, 7)
d1
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
d2 = np.arange(1, 7)
d2
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
mat=np.add.outer(d1,d2)
mat
# Out:
# array([[ 2,  3,  4,  5,  6,  7],
#        [ 3,  4,  5,  6,  7,  8],
#        [ 4,  5,  6,  7,  8,  9],
#        [ 5,  6,  7,  8,  9, 10],
#        [ 6,  7,  8,  9, 10, 11],
#        [ 7,  8,  9, 10, 11, 12]])

# %%
mat.size
# Out:
# 36

# %%
# diagonally we get 6 seven's
mat[mat==7].size
# Out:
# 6

# %%
# getting probability
#results.mean()/1000   =   0.16730799999999998  so means very close
mat[mat==7].size/mat.size
# Out:
# 0.16666666666666666

# %%
#Monte Carlo Simulation with Portfolios and Sharpe Ratio for 
#getting the perfect balance of our stocks
import pandas_datareader as pdr
import datetime as dt
import pandas as pd

# %%
tickers = ['AAPL', 'MSFT', 'TWTR', 'IBM']
start = dt.datetime(2020, 1, 1)

data = pdr.get_data_yahoo(tickers, start)

# %%
data = data['Adj Close']

# %%
data.head()
# Out:
# Symbols          AAPL        MSFT       TWTR         IBM
# Date
# 2020-01-02  73.988472  157.615112  32.299999  117.120605
# 2020-01-03  73.269150  155.652512  31.520000  116.186539
# 2020-01-06  73.852989  156.054855  31.639999  115.978966
# 2020-01-07  73.505661  154.632004  32.540001  116.056808
# 2020-01-08  74.688080  157.095047  33.049999  117.025467

# %%
log_returns = np.log(data/data.shift())

# %%
log_returns
# Out:
# Symbols         AAPL      MSFT      TWTR       IBM
# Date
# 2020-01-02       NaN       NaN       NaN       NaN
# 2020-01-03 -0.009770 -0.012530 -0.024445 -0.008007
# 2020-01-06  0.007937  0.002581  0.003800 -0.001788
# 2020-01-07 -0.004714 -0.009159  0.028048  0.000671
# 2020-01-08  0.015958  0.015803  0.015551  0.008312
# ...              ...       ...       ...       ...
# 2022-01-14  0.005098  0.017562 -0.006741 -0.004090
# 2022-01-18 -0.019075 -0.024640 -0.030105 -0.009508
# 2022-01-19 -0.021249  0.002244  0.001340 -0.010283
# 2022-01-20 -0.010401 -0.005720 -0.001876 -0.005793
# 2022-01-21 -0.012847 -0.018641 -0.068265 -0.011300
#
# [519 rows x 4 columns]

# %%
weight = np.random.random(4)
weight /= weight.sum()
weight
# Out:
# array([0.36978408, 0.03020902, 0.32200133, 0.27800557])

# %%
#expected return
exp_rtn = np.sum(log_returns.mean()*weight)*252

# %%
exp_rtn
# Out:
# 0.17589975687951134

# %%
#expected volatility
# to speed up using this formula
exp_vol = np.sqrt(np.dot(weight.T, np.dot(log_returns.cov()*252, weight)))
exp_vol
# Out:
# 0.33074319749107745

# %%
# exp return/ expected volatility
sharpe_ratio = exp_rtn / exp_vol
sharpe_ratio
# Out:
# 0.5318318206204578

# %%
# Monte Carlo Simulation
#runs=5000
n = 5000

weights = np.zeros((n, 4))
exp_rtns = np.zeros(n)
exp_vols = np.zeros(n)
sharpe_ratios = np.zeros(n)

for i in range(n):
    weight = np.random.random(4)
    weight /= weight.sum()
    weights[i] = weight
    
    exp_rtns[i] = np.sum(log_returns.mean()*weight)*252
    exp_vols[i] = np.sqrt(np.dot(weight.T, np.dot(log_returns.cov()*252, weight)))
    sharpe_ratios[i] = exp_rtns[i] / exp_vols[i]

# %%
sharpe_ratios.max()
# Out:
# 1.006764007270229

# %%
sharpe_ratios.argmax()
# Out:
# 2046

# %%
#apple and microsoft are high and twitter and ibm has low
weights[600]
# Out:
# array([0.27745458, 0.15735124, 0.40245007, 0.1627441 ])

# %%
fig,ax=plt.subplots()
ax.scatter(exp_vols,exp_rtns,c=sharpe_ratios)
ax.scatter(exp_vols[sharpe_ratios.argmax()],exp_rtns[sharpe_ratios.argmax()],c='r')
ax.set_xlabel('Expected Volatility')
ax.set_ylabel('Expected Return')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Expected Return')

# %%
#Correlation
#Correlation measures association, but doesn't show if x causes y or vice versa
#Correlation is a statistic that measures the degree to which two variables move in relation to each other.
#In finance, the correlation can measure the movement of a stock with that of a benchmark index, 
#Formula


#r: the correlation factor
#X(bar): the average observations of X
#Y(bar): the average observations of Y
#What does it mean?

 #r=ranges between -1 and 1 (both inclusive)
#r=1: Perfect positive correlation
#r=-1: Perfect negative correlation
#r=0: No correlation at all

# %%
#CALCULATING CORRELATION
# if one goes down then other also
import pandas as pd
import pandas_datareader as pdr
import datetime as dt
import numpy as np

# %%
tickers = ['AAPL', 'TWTR', 'IBM', 'MSFT']
start = dt.datetime(2020, 1, 1)

data = pdr.get_data_yahoo(tickers, start)

# %%
data.head()
# Out:
# Attributes  Adj Close                                         Close  \
# Symbols          AAPL       TWTR         IBM        MSFT       AAPL
# Date
# 2020-01-02  73.894333  32.299999  115.261650  157.289871  75.087502
# 2020-01-03  73.175919  31.520000  114.342430  155.331360  74.357498
# 2020-01-06  73.759018  31.639999  114.138161  155.732834  74.949997
# 2020-01-07  73.412109  32.540001  114.214729  154.312897  74.597504
# 2020-01-08  74.593056  33.049999  115.168030  156.770859  75.797501
#
# Attributes                                          High             ...  \
# Symbols          TWTR         IBM        MSFT       AAPL       TWTR  ...
# Date                                                                 ...
# 2020-01-02  32.299999  129.464630  160.619995  75.150002  32.500000  ...
# 2020-01-03  31.520000  128.432129  158.619995  75.144997  32.099998  ...
# 2020-01-06  31.639999  128.202682  159.029999  74.989998  31.709999  ...
# ...

# %%
data = data['Adj Close']

# %%
data.head()
# Out:
# Symbols          AAPL       TWTR         IBM        MSFT
# Date
# 2020-01-02  73.894333  32.299999  115.261650  157.289871
# 2020-01-03  73.175919  31.520000  114.342430  155.331360
# 2020-01-06  73.759018  31.639999  114.138161  155.732834
# 2020-01-07  73.412109  32.540001  114.214729  154.312897
# 2020-01-08  74.593056  33.049999  115.168030  156.770859

# %%
log_returns = np.log(data/data.shift())

# %%
log_returns
# Out:
# Symbols         AAPL      TWTR       IBM      MSFT
# Date
# 2020-01-02       NaN       NaN       NaN       NaN
# 2020-01-03 -0.009770 -0.024445 -0.008007 -0.012530
# 2020-01-06  0.007937  0.003800 -0.001788  0.002581
# 2020-01-07 -0.004714  0.028048  0.000671 -0.009160
# 2020-01-08  0.015959  0.015551  0.008312  0.015803
# ...              ...       ...       ...       ...
# 2022-03-17  0.006433  0.053129  0.007216  0.002815
# 2022-03-18  0.020703  0.012522  0.006232  0.017494
# 2022-03-21  0.008501 -0.008776 -0.005139 -0.004236
# 2022-03-22  0.020587  0.026099  0.007466  0.016246
# 2022-03-22  0.000000  0.000000  0.000000  0.000000
#
# [561 rows x 4 columns]

# %%
#apple with apple 1 and same with others
log_returns.corr()
# Out:
# Symbols      AAPL      TWTR       IBM      MSFT
# Symbols
# AAPL     1.000000  0.506469  0.451873  0.807215
# TWTR     0.506469  1.000000  0.308227  0.528803
# IBM      0.451873  0.308227  1.000000  0.481457
# MSFT     0.807215  0.528803  0.481457  1.000000

# %%
# The S&P 500 index, or Standard & Poor's 500, is a very
#important index that tracks the performance of the stocks
#of 500 large-cap companies in the U.S. The ticker symbol
#for the S&P 500 index is ^GSPC. The series of letters
#represents the performance of the 500 stocks listed on 
#the S&P.
sp500 = pdr.get_data_yahoo("^GSPC", start)

# %%
log_returns['SP500'] = np.log(sp500['Adj Close']/sp500['Adj Close'].shift())

# %%
# SP500 has high correlation with aple and microsoft and even with other too
# bad thing is that if SP500 goes down others will also goes down
log_returns.corr()
# Out:
# Symbols      AAPL      TWTR       IBM      MSFT     SP500
# Symbols
# AAPL     1.000000  0.506469  0.451873  0.807215  0.805565
# TWTR     0.506469  1.000000  0.308227  0.528803  0.583776
# IBM      0.451873  0.308227  1.000000  0.481457  0.707520
# MSFT     0.807215  0.528803  0.481457  1.000000  0.852766
# SP500    0.805565  0.583776  0.707520  0.852766  1.000000

# %%
def test_correlation(ticker):
    df = pdr.get_data_yahoo(ticker, start)
    lr = log_returns.copy()
    lr[ticker] = np.log(df['Adj Close']/df['Adj Close'].shift())
    return lr.corr()

# %%
#want to test correlation ,lets take LQD as instance
#iShares iBoxx USD Investment Grade Corporate Bond ETF (LQD) and iShares 20+ Year Treasury Bond ETF (TLT). 
#Both ETFs trade in the U.S. markets. LQD launched on 07/22/02, while TLT debuted on 07/22/02. 
#What Is an ETF?      An exchange traded fund (ETF)
test_correlation("LQD")
# it has +ve correlation(all values +ve)
# Out:
# Symbols      AAPL      TWTR       IBM      MSFT     SP500       LQD
# Symbols
# AAPL     1.000000  0.506469  0.451873  0.807215  0.805565  0.255016
# TWTR     0.506469  1.000000  0.308227  0.528803  0.583776  0.234308
# IBM      0.451873  0.308227  1.000000  0.481457  0.707520  0.224762
# MSFT     0.807215  0.528803  0.481457  1.000000  0.852766  0.272525
# SP500    0.805565  0.583776  0.707520  0.852766  1.000000  0.308361
# LQD      0.255016  0.234308  0.224762  0.272525  0.308361  1.000000

# %%
# -ve correlation(some vales are -ve in it)
test_correlation("TLT")
# Out:
# Symbols      AAPL      TWTR       IBM      MSFT     SP500       TLT
# Symbols
# AAPL     1.000000  0.506469  0.451873  0.807215  0.805565 -0.257060
# TWTR     0.506469  1.000000  0.308227  0.528803  0.583776 -0.130158
# IBM      0.451873  0.308227  1.000000  0.481457  0.707520 -0.362811
# MSFT     0.807215  0.528803  0.481457  1.000000  0.852766 -0.239017
# SP500    0.805565  0.583776  0.707520  0.852766  1.000000 -0.378724
# TLT     -0.257060 -0.130158 -0.362811 -0.239017 -0.378724  1.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
#df = df/df.iloc[0] means normalizing Adj Close
def visualize_correlation(ticker1, ticker2):
    df = pdr.get_data_yahoo([ticker1, ticker2], start)
    df = df['Adj Close']
    df = df/df.iloc[0]
    fig, ax = plt.subplots()
    df.plot(ax=ax)

# %%
#graph shows -ve correlation b/w two
visualize_correlation("AAPL", "TLT")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# identifyig how much your portfolios are at risk with -ve coorelation
visualize_correlation("^GSPC", "TLT")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#LINEAR REGRESSION:
#Attempts to establish how X causes Y
#Correlation vs Linear Regression
#Similarities

#Quantify the direction and strength of the relationship
#Differences

#Correlation is a single statistic
#Linear regression produces an equation

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas_datareader as pdr
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
X = np.random.randn(5000)
Y = np.random.randn(5000)

fig, ax = plt.subplots()
ax.scatter(X, Y, alpha=.2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tickers = ['AAPL', 'TWTR', 'IBM', 'MSFT', '^GSPC']
start = dt.datetime(2020, 1, 1)

data = pdr.get_data_yahoo(tickers, start)

# %%
data = data['Adj Close']

# %%
data.head()
# Out:
# Symbols          AAPL       TWTR         IBM        MSFT        ^GSPC
# Date
# 2020-01-02  73.894325  32.299999  115.261650  157.289871  3257.850098
# 2020-01-03  73.175919  31.520000  114.342415  155.331329  3234.850098
# 2020-01-06  73.759010  31.639999  114.138161  155.732864  3246.280029
# 2020-01-07  73.412125  32.540001  114.214737  154.312897  3237.179932
# 2020-01-08  74.593040  33.049999  115.168030  156.770874  3253.050049

# %%
log_returns = np.log(data/data.shift())

# %%
log_returns
# Out:
# Symbols         AAPL      TWTR       IBM      MSFT     ^GSPC
# Date
# 2020-01-02       NaN       NaN       NaN       NaN       NaN
# 2020-01-03 -0.009770 -0.024445 -0.008007 -0.012530 -0.007085
# 2020-01-06  0.007937  0.003800 -0.001788  0.002582  0.003527
# 2020-01-07 -0.004714  0.028048  0.000671 -0.009160 -0.002807
# 2020-01-08  0.015958  0.015551  0.008312  0.015803  0.004890
# ...              ...       ...       ...       ...       ...
# 2022-03-17  0.006433  0.053129  0.007216  0.002815  0.012272
# 2022-03-18  0.020703  0.012522  0.006232  0.017494  0.011595
# 2022-03-21  0.008501 -0.008776 -0.005139 -0.004236 -0.000435
# 2022-03-22  0.020587  0.026099  0.007466  0.016246  0.011241
# 2022-03-22  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [561 rows x 5 columns]

# %%
#X = log_returns[ticker_a].iloc[1:].to_numpy().reshape(-1, 1)
#Y = log_returns[ticker_b].iloc[1:].to_numpy().reshape(-1, 1)
#above two remove 1st row from tcker 1(AAPL) and ticker2(GSPC) because it is Nan
def linear_regression(ticker_a, ticker_b):
    X = log_returns[ticker_a].iloc[1:].to_numpy().reshape(-1, 1)
    Y = log_returns[ticker_b].iloc[1:].to_numpy().reshape(-1, 1)
#fitted the model
    lin_regr = LinearRegression()
    lin_regr.fit(X, Y)

    Y_pred = lin_regr.predict(X)

    alpha = lin_regr.intercept_[0]
    beta = lin_regr.coef_[0, 0]
    print(alpha)
    print(beta)
    

    
    
    
    
    fig, ax = plt.subplots()
    ax.set_title("Alpha: " + str(round(alpha, 5)) + ", Beta: " + str(round(beta, 3)))
    ax.scatter(X, Y)
    ax.plot(X, Y_pred, c='r')

# %%
linear_regression("AAPL", "^GSPC")
# Out:
# -0.0002510390640429051
# 0.5642339342655067
# <img src="data:image/png;base64,..." width="640">

# %%
linear_regression("AAPL", "MSFT")
# Out:
# 6.584425875840881e-05
# 0.7531639438333618
# <img src="data:image/png;base64,..." width="640">

# %%
linear_regression("AAPL", "TWTR")
# Out:
# -0.0007873341036123858
# 0.7439850961818809
# <img src="data:image/png;base64,..." width="640">

# %%
#CALCULATING BETA
#Beta
#Beta is a measure of a stock's volatility in relation to the overall market.
#S&P 500 Index has a beta of 1.0
#High-beta stocks are supposed to be riskier but provide higher return potential.
#Low-beta stocks pose less risk but also lower returns.
#Formula  Beta=covariance/variance
 
#Interpretation
#Beta above 1: stock is more volatile than the market, but expects higher return
#Beta below 1: stock with lower volatility, and expects less returN

import numpy as np
import pandas_datareader as pdr
import datetime as dt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
#interval="m"  means monthly basis
tickers = ['AAPL', 'MSFT', 'TWTR', 'IBM', '^GSPC']
start = dt.datetime(2015, 12, 1)
end = dt.datetime(2021, 1, 1)

data = pdr.get_data_yahoo(tickers, start, end, interval="m")

# %%
data = data['Adj Close']

# %%
log_returns = np.log(data/data.shift())

# %%
log_returns
# Out:
# Symbols         AAPL      MSFT      TWTR       IBM     ^GSPC
# Date
# 2015-12-01       NaN       NaN       NaN       NaN       NaN
# 2016-01-01 -0.078223 -0.007054 -0.320184 -0.097864 -0.052068
# 2016-02-01 -0.006700 -0.079498  0.075638  0.048794 -0.004137
# 2016-03-01  0.125158  0.089191 -0.090630  0.155462  0.063905
# 2016-04-01 -0.150731 -0.102086 -0.123996 -0.037060  0.002696
# ...              ...       ...       ...       ...       ...
# 2020-09-01 -0.106370 -0.067361  0.092214  0.000222 -0.040018
# 2020-10-01 -0.061888 -0.038086 -0.073175 -0.085854 -0.028056
# 2020-11-01  0.089481  0.055711  0.117353  0.100944  0.102146
# 2020-12-01  0.110196  0.040879  0.152091  0.033990  0.036449
# 2021-01-01 -0.005517  0.041998 -0.069191 -0.055282 -0.011199
#
# [62 rows x 5 columns]

# %%
cov = log_returns.cov()
cov
# Out:
# Symbols      AAPL      MSFT      TWTR       IBM     ^GSPC
# Symbols
# AAPL     0.007254  0.002920  0.003730  0.002452  0.002413
# MSFT     0.002920  0.002638  0.000738  0.001902  0.001534
# TWTR     0.003730  0.000738  0.019788  0.001908  0.001795
# IBM      0.002452  0.001902  0.001908  0.005319  0.002401
# ^GSPC    0.002413  0.001534  0.001795  0.002401  0.001924

# %%
var = log_returns['^GSPC'].var()

# %%
var
# Out:
# 0.0019235693497498328

# %%
#covarianc of Apple
#it means if general market goes up 10% then AAPL goes up 12.5%
cov.loc['AAPL', '^GSPC']/var
# Out:
# 1.2545571785652343

# %%
# verify value of cov of apple,same value
cov.loc['^GSPC']/var
# Out:
# Symbols
# AAPL     1.254557
# MSFT     0.797269
# TWTR     0.933242
# IBM      1.248307
# ^GSPC    1.000000
# Name: ^GSPC, dtype: float64

# %%
#another way of doing same above
X = log_returns['^GSPC'].iloc[1:].to_numpy().reshape(-1, 1)
Y = log_returns['AAPL'].iloc[1:].to_numpy().reshape(-1, 1)

lin_regr = LinearRegression()
lin_regr.fit(X, Y)
# beta value,getting same value again
lin_regr.coef_[0, 0]
# Out:
# 1.2545571785652339

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
fig, ax = plt.subplots()
ax.scatter(X, Y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#CAPM
#Capital Asset Pricing Model (CAPM)

#Relationship between systematic risk and expected return

#There are several assumptions behind the CAPM formula that have been shown not to hold in reality.

#CAPM formula is still widely used
#FORMULA= ERi=Rf+BETAi(ERm-Rf)

#ERi=expected return from investment

#Rf=Risk free return

#BETAi=the beta of investment

#(ERm-Rf)=Market risk premium

#The capital asset pricing model (CAPM) helps to calculate investment risk and what return on investment an 
#investor should expect.

import numpy as np
import pandas_datareader as pdr
import datetime as dt
import pandas as pd

# %%
tickers = ['AAPL', 'MSFT', 'TWTR', 'IBM', '^GSPC']
start = dt.datetime(2015, 12, 1)
end = dt.datetime(2021, 1, 1)

data = pdr.get_data_yahoo(tickers, start, end, interval="m")

# %%
data = data['Adj Close']

# %%
log_returns = np.log(data/data.shift())

# %%
cov = log_returns.cov()
var = log_returns['^GSPC'].var()

# %%
beta = cov.loc['AAPL', '^GSPC']/var
beta
# Out:
# 1.254557534681412

# %%
risk_free_return = 0.0138
market_return = .105
expected_return = risk_free_return + beta*(market_return - risk_free_return)

# %%
expected_return
# Out:
# 0.12821564716294478

# %%
beta*market_return
# Out:
# 0.13172854114154825

# %%
beta = cov.loc['^GSPC']/var

# %%
beta
# Out:
# Symbols
# AAPL     1.254558
# MSFT     0.797269
# TWTR     0.933242
# IBM      1.249102
# ^GSPC    1.000000
# Name: ^GSPC, dtype: float64

# %%
market_return = risk_free_return + beta*(market_return - risk_free_return)

# %%
market_return
# Out:
# Symbols
# AAPL     0.128216
# MSFT     0.086511
# TWTR     0.098912
# IBM      0.127718
# ^GSPC    0.105000
# Name: ^GSPC, dtype: float64

# %%
# estimating the stock beta via python-CAPM Regression
import pandas_datareader.data as reader
import datetime as dt
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
end=dt.datetime.now()
start=dt.date(end.year-5,end.month,end.day)
Input=['MSFT','^GSPC']

# %%
df=reader.get_data_yahoo(Input,start,end)['Adj Close']
df
# Out:
# Symbols           MSFT        ^GSPC
# Date
# 2017-03-23   60.555161  2345.959961
# 2017-03-24   60.657841  2343.979980
# 2017-03-27   60.769852  2341.590088
# 2017-03-28   60.947220  2358.570068
# 2017-03-29   61.115253  2361.129883
# ...                ...          ...
# 2022-03-17  295.220001  4411.669922
# 2022-03-18  300.429993  4463.120117
# 2022-03-21  299.160004  4461.180176
# 2022-03-22  304.059998  4511.609863
# 2022-03-22  304.059998  4511.609863
#
# [1260 rows x 2 columns]

# %%
# as we are intersted in monthly returns ,let's calculate them
#mtl_ret=df.resample('M').ffill().pct_change()

mtl_ret = df.resample('M').last().ffill().pct_change()
mtl_ret
# delete first row
mtl_ret=mtl_ret.dropna(axis=0)
mtl_ret.head()
# Out:
# Symbols         MSFT     ^GSPC
# Date
# 2017-04-30  0.039477  0.009091
# 2017-05-31  0.026005  0.011576
# 2017-06-30 -0.013030  0.004814
# 2017-07-31  0.054693  0.019349
# 2017-08-31  0.033953  0.000546

# %%
# building regression model
#define dependent and independent variable
X=mtl_ret['^GSPC']
y=mtl_ret['MSFT']
# adding intercept(by default not present)
X_sm=sm.add_constant(X)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
#building model using Ordinary Least Square Approach(OLS)
model=sm.OLS(y,X_sm)
results=model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MSFT   R-squared:                       0.570
# Model:                            OLS   Adj. R-squared:                  0.563
# Method:                 Least Squares   F-statistic:                     76.94
# Date:                Wed, 23 Mar 2022   Prob (F-statistic):           3.16e-12
# Time:                        07:01:41   Log-Likelihood:                 115.10
# No. Observations:                  60   AIC:                            -226.2
# Df Residuals:                      58   BIC:                            -222.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0177      0.005      3.662      0.001       0.008       0.027
# ...

# %%
# from results.summary output, ( const coef   =0.0175) which is alpha, (^GSPC coef=0.9046) which is beta
# visualization
import seaborn as sns
sns.regplot(x='^GSPC',y='MSFT',data=mtl_ret)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Get Financial Data from Yahoo Finance with Python
pip install yfinance
# Out:
#   File "C:\Users\profn\AppData\Local\Temp/ipykernel_19224/3572290430.py", line 2
#     pip install yfinance
#         ^
# SyntaxError: invalid syntax

# %%
# This repository, matplotlib/mplfinance , contains a new matplotlib finance API that makes it easier to create
#financial plots. It interfaces nicely with Pandas DataFrames. More importantly, the new API automatically does the
#extra matplotlib work that the user previously had to do "manually" with the old API.
pip install mplfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
import yfinance as yf
import mplfinance as mpf
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Basic information
tsla = yf.Ticker("TSLA")
tsla.info
# Out:
# {'zip': '78725',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 99290,
# ...

# %%
#Market cap—or market capitalization—refers to the total value of all a company's shares of stock. ...
print(f"Market Cap : {tsla.info['marketCap']}\n")
print(f"Employees : {tsla.info['fullTimeEmployees']}\n")
print(f"Business Summary : \n{tsla.info['longBusinessSummary']}")
# Out:
# Market Cap : 1027288268800
#
# Employees : 99290
#
# Business Summary :
# ...

# %%
# OHLCV data like open,high ,low,close,volume,dividends and stock splits
# for previous days
tsla.history(period='5d')
# Out:
#                  Open        High         Low       Close    Volume  \
# Date
# 2022-03-16  809.00000  842.000000  802.260010  840.229980  28009600
# 2022-03-17  830.98999  875.000000  825.719971  871.599976  22194300
# 2022-03-18  874.48999  907.849976  867.390015  905.390015  33408500
# 2022-03-21  914.97998  942.849976  907.090027  921.159973  27327200
# 2022-03-22  930.00000  997.859985  921.750000  993.979980  35200400
#
#             Dividends  Stock Splits
# Date
# 2022-03-16          0             0
# 2022-03-17          0             0
# 2022-03-18          0             0
# 2022-03-21          0             0
# 2022-03-22          0             0

# %%
#Remove actions means remove dividend and stock splits
tsla.history(period='5d', actions=False)
# Out:
#                  Open        High         Low       Close    Volume
# Date
# 2022-03-16  809.00000  842.000000  802.260010  840.229980  28009600
# 2022-03-17  830.98999  875.000000  825.719971  871.599976  22194300
# 2022-03-18  874.48999  907.849976  867.390015  905.390015  33408500
# 2022-03-21  914.97998  942.849976  907.090027  921.159973  27327200
# 2022-03-22  930.00000  997.859985  921.750000  993.979980  35200400

# %%
#Getting data using start date and end date
tsla=yf.Ticker('tsla')
tsla.history(start="2021-02-20", end="2021-03-01", actions=False)
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2021-02-22  762.640015  768.500000  710.200012  714.500000  37269700
# 2021-02-23  662.130005  713.609985  619.000000  698.840027  66606900
# 2021-02-24  711.849976  745.000000  694.169983  742.020020  36767000
# 2021-02-25  726.150024  737.210022  670.580017  682.219971  39023900
# 2021-02-26  700.000000  706.700012  659.510010  675.500000  41089200

# %%
# fetching multiple tickers means multiple companies
#Year to date (YTD) refers to the period of time beginning the first day of the current calendar year or fiscal year up

#to the current date. YTD information is useful for analyzing business trends over time or comparing performance data to 

#competitors or peers in the same industry.

data = yf.download("AMZN AAPL TSLA", period="ytd",
        group_by='ticker', actions=False)
amzn=data["AMZN"]
aapl=data["AAPL"]
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
amzn.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-01-03  3351.000000  3414.070068  3323.209961  3408.090088  3408.090088
# 2022-01-04  3408.760010  3428.000000  3326.989990  3350.439941  3350.439941
# 2022-01-05  3337.659912  3342.530029  3287.139893  3287.139893  3287.139893
# 2022-01-06  3269.010010  3296.000000  3238.739990  3265.080078  3265.080078
# 2022-01-07  3276.780029  3304.870117  3240.620117  3251.080078  3251.080078
#
#              Volume
# Date
# 2022-01-03  3176000
# 2022-01-04  3536300
# 2022-01-05  3215100
# 2022-01-06  2597900
# 2022-01-07  2330300

# %%
# convert data into csv
amzn.to_csv('amzn.csv')

# %%
#Other functions in Ticker Module
#actions
aapl=yf.Ticker('AAPL')
aapl.actions.tail(5)
# Out:
#             Dividends  Stock Splits
# Date
# 2021-02-05      0.205           0.0
# 2021-05-07      0.220           0.0
# 2021-08-06      0.220           0.0
# 2021-11-05      0.220           0.0
# 2022-02-04      0.220           0.0

# %%
#dividends
aapl.dividends.tail()
# Out:
# Date
# 2021-02-05    0.205
# 2021-05-07    0.220
# 2021-08-06    0.220
# 2021-11-05    0.220
# 2022-02-04    0.220
# Name: Dividends, dtype: float64

# %%
#splits
aapl.splits.tail()
# Out:
# Date
# 1987-06-16    2.0
# 2000-06-21    2.0
# 2005-02-28    2.0
# 2014-06-09    7.0
# 2020-08-31    4.0
# Name: Stock Splits, dtype: float64

# %%
#major_holders
aapl.major_holders
# Out:
#         0                                      1
# 0   0.07%        % of Shares Held by All Insider
# 1  59.44%       % of Shares Held by Institutions
# 2  59.48%        % of Float Held by Institutions
# 3    5443  Number of Institutions Holding Shares

# %%
#institutional_holders
aapl.institutional_holders
# Out:
#                                 Holder      Shares Date Reported   % Out  \
# 0           Vanguard Group, Inc. (The)  1261261357    2021-12-30  0.0773
# 1                       Blackrock Inc.  1019810291    2021-12-30  0.0625
# 2              Berkshire Hathaway, Inc   887135554    2021-12-30  0.0544
# 3             State Street Corporation   633115246    2021-12-30  0.0388
# 4                             FMR, LLC   352204129    2021-12-30  0.0216
# 5        Geode Capital Management, LLC   264351901    2021-12-30  0.0162
# 6        Price (T.Rowe) Associates Inc   223148792    2021-12-30  0.0137
# 7           Northern Trust Corporation   190876014    2021-12-30  0.0117
# 8  Bank Of New York Mellon Corporation   144695935    2021-12-30  0.0089
# 9    Norges Bank Investment Management   142076403    2021-12-30  0.0087
#
#           Value
# 0  223962179162
# 1  181087713372
# 2  157528660323
# 3  112422274232
# 4   62540887186
# 5   46940967060
# 6   39624530995
# 7   33893853805
# ...

# %%
#sustainability data
aapl.sustainability
# Out:
#                                      Value
# 2021-9
# palmOil                              False
# controversialWeapons                 False
# gambling                             False
# socialScore                           7.99
# nuclear                              False
# furLeather                           False
# alcoholic                            False
# gmo                                  False
# catholic                             False
# socialPercentile                      None
# peerCount                               53
# governanceScore                       8.64
# environmentPercentile                 None
# animalTesting                        False
# tobacco                              False
# totalEsg                             16.92
# highestControversy                       3
# esgPerformance                  UNDER_PERF
# coal                                 False
# pesticides                           False
# adult                                False
# ...

# %%
#Analyst recommendations,tail for latest data
aapl.recommendations.tail()
# Out:
#                                     Firm      To Grade From Grade Action
# Date
# 2022-01-28 14:19:01  New Street Research       Neutral       Sell     up
# 2022-01-28 15:10:56          Oppenheimer    Outperform              main
# 2022-01-31 15:44:19        Credit Suisse       Neutral              main
# 2022-02-15 15:31:58    Tigress Financial    Strong Buy              main
# 2022-03-11 11:57:08             Barclays  Equal-Weight              main

# %%
# Show the upcoming events
aapl.calendar
# Out:
#                                     0                    1
# Earnings Date     2022-04-26 20:00:00  2022-05-02 20:00:00
# Earnings Average                 1.43                 1.43
# Earnings Low                     1.34                 1.34
# Earnings High                    1.56                 1.56
# Revenue Average           94009300000          94009300000
# Revenue Low               90042000000          90042000000
# Revenue High             100444000000         100444000000

# %%
# Show ISIN code
#An International Securities Identification Number (ISIN) is a 12-digit alphanumeric code that uniquely identifies a specific security.
aapl.isin
# Out:
# 'US0378331005'

# %%
# Available option expiration dates
aapl.options
# Out:
# ('2022-03-25',
#  '2022-04-01',
#  '2022-04-08',
#  '2022-04-14',
#  '2022-04-22',
#  '2022-04-29',
#  '2022-05-20',
#  '2022-06-17',
#  '2022-07-15',
#  '2022-08-19',
#  '2022-09-16',
#  '2022-10-21',
#  '2022-11-18',
#  '2023-01-20',
#  '2023-03-17',
#  '2023-06-16',
#  '2023-09-15',
#  '2024-01-19',
#  '2024-06-21')
